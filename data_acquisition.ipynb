# %% [markdown]
# ## Comparison of orbital launch systems
#
# - <https://en.wikipedia.org/wiki/Comparison_of_orbital_launch_systems>

# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Comparison_of_orbital_launch_systems'
dfs = pd.read_html(url)

# %% [markdown]
# ### Current rockets

# %%
dfs[0]
# Out:
#                Vehicle         Origin     Manufacturer  Height  \
#                Vehicle         Origin     Manufacturer  Height
# 0   Angara A5 / Briz-M         Russia       Khrunichev  48.7 m
# 1           Angara-1.2         Russia       Khrunichev  42.7 m
# 2         Ariane 6 A62         France      ArianeGroup    63 m
# 3          Atlas V 551  United States              ULA  58.3 m
# 4       Atlas V N22[b]  United States              ULA  52.4 m
# ..                 ...            ...              ...     ...
# 83                SSLV          India             ISRO    34 m
# 84          Tianlong-2          China    Space Pioneer  32.8 m
# 85              Vega-C          Italy  ArianeGroupAvio  36.2 m
# 86  Vulcan Centaur VC2  United States              ULA  61.6 m
# 87           Zhuque-2E          China        LandSpace  49.5 m
#
#    Maximum payload mass (kg)              \
#                          LEO         GTO
# 0                  24,500[1]    5,200[1]
# ...

# %% [markdown]
# ### Rockets in flight testing

# %%
dfs[1]
# Out:
#                                   Vehicle               Origin  \
#                                   Vehicle               Origin
# 0                       Angara A5 / Orion               Russia
# 1                      Angara A5 / Persei               Russia
# 2                                GYUB TV2          South Korea
# 3                                  KAIROS                Japan
# 4  New-type satellite carrier rocket[143]  North Korea  Russia
# 5                               New Glenn        United States
# 6                        Starship Block 2        United States
# 7                                Spectrum              Germany
#
#       Manufacturer   Height Maximum payload mass (kg)               \
#       Manufacturer   Height                       LEO          GTO
# 0       Khrunichev   54.9 m                       NaN   6,500[139]
# 1       Khrunichev   54.9 m                       NaN   6,500[139]
# ...

# %% [markdown]
# ### Upcoming rockets

# %%
dfs[2]
# Out:
#              Vehicle  Origin               Manufacturer  Height  \
#              Vehicle  Origin               Manufacturer  Height
# 0           Agnibaan   India             AgniKul Cosmos    18 m
# 1   Angara A5 / KVTK  Russia                 Khrunichev     NaN
# 2         Angara A5M  Russia                 Khrunichev     NaN
# 3         Angara A5P  Russia                 Khrunichev     NaN
# 4         Angara A5V  Russia                 Khrunichev    70 m
# ..               ...     ...                        ...     ...
# 75              Zero   Japan  Interstellar Technologies    32 m
# 76          Zhuque-3   China                  LandSpace  76.6 m
# 77          Zhuque-3   China                  LandSpace  76.6 m
# 78          Zhuque-3   China                  LandSpace  76.6 m
# 79          Zuljanah    Iran       Iranian Space Agency  25.5 m
#
#    Payload mass to ... (kg)                    \
#                         LEO               GTO
# ...

# %% [markdown]
# ### Retired launch systems
#
# - <https://en.wikipedia.org/wiki/Comparison_of_retired_orbital_launch_systems>

# %%
url_ret = 'https://en.wikipedia.org/wiki/Comparison_of_retired_orbital_launch_systems'
dfs_ret = pd.read_html(url_ret)

# %%
dfs_ret[1]
# Out:
#                 Vehicle         Origin          Manufacturer       Height  \
#                 Vehicle         Origin          Manufacturer       Height
# 0       Antares 110–130  United States               Orbital  40.5-41.9 m
# 1    Antares 230 / 230+  United States      Northrop Grumman       42.5 m
# 2              Ariane 1         France          Aérospatiale       49.1 m
# 3              Ariane 2         France          Aérospatiale       49.1 m
# 4              Ariane 3         France          Aérospatiale       49.1 m
# ..                  ...            ...                   ...          ...
# 187            Zenit-2M        Ukraine              Yuzhnoye         57 m
# 188            Zenit-3F        Ukraine              Yuzhnoye       59.6 m
# 189           Zenit-3SL        Ukraine  Yuzhmash RSC Energia       59.6 m
# 190          Zenit-3SLB        Ukraine  Yuzhmash RSC Energia       59.5 m
# 191            Zhuque-1          China             LandSpace         19 m
#
# ...

# %%
dfs_ret[2]
# Out:
#                  Vehicle         Origin                       Manufacturer  \
#                  Vehicle         Origin                       Manufacturer
# 0             Atlas-Able  United States                   General Dynamics
# 1            Atlas-Agena  United States           Convair/General Dynamics
# 2          Atlas-Centaur  United States                           Lockheed
# 3                Atlas B  United States                    Lockheed Martin
# 4            Atlas-D OV1  United States           Convair/General Dynamics
# 5        Atlas E/F-Agena  United States  Convair/General Dynamics/Lockheed
# 6    Atlas E/F-Altair-3A  United States           Convair/General Dynamics
# 7     Atlas E/F-Burner-2  United States           Convair/General Dynamics
# 8          Atlas E/F-MSD  United States           Convair/General Dynamics
# 9          Atlas E/F-OIS  United States           Convair/General Dynamics
# ...

# %%
dfs_ret[3]
# Out:
#              Vehicle         Origin       Manufacturer  Height  \
#              Vehicle         Origin       Manufacturer  Height
# 0         Delta 0300  United States  McDonnell Douglas    34 m
# 1         Delta 0900  United States  McDonnell Douglas    34 m
# 2         Delta 1410  United States  McDonnell Douglas  35.2 m
# 3         Delta 1604  United States  McDonnell Douglas  35.2 m
# 4         Delta 1900  United States  McDonnell Douglas  35.2 m
# 5         Delta 1910  United States  McDonnell Douglas  35.2 m
# 6         Delta 1913  United States  McDonnell Douglas  35.2 m
# 7         Delta 1914  United States  McDonnell Douglas  35.2 m
# 8         Delta 2310  United States  McDonnell Douglas  35.2 m
# 9         Delta 2313  United States  McDonnell Douglas  35.2 m
# 10        Delta 2910  United States  McDonnell Douglas  35.2 m
# 11        Delta 2913  United States  McDonnell Douglas  35.2 m
# 12        Delta 2914  United States  McDonnell Douglas  35.2 m
# ...

# %%
dfs_ret[4]
# Out:
#                    Vehicle         Origin      Manufacturer  Height  \
#                    Vehicle         Origin      Manufacturer  Height
# 0              Thor-Able I  United States   Douglas/Aerojet  26.9 m
# 1             Thor-Able II  United States   Douglas/Aerojet  27.3 m
# 2            Thor-Able III  United States   Douglas/Aerojet  27.4 m
# 3             Thor-Able IV  United States   Douglas/Aerojet  27.2 m
# 4             Thor Agena-A  United States  Douglas/Lockheed  22.7 m
# 5             Thor Agena-B  United States  Douglas/Lockheed  26.3 m
# 6             Thor Agena-D  United States  Douglas/Lockheed  29.3 m
# 7    Thorad SLV-2G Agena D  United States  Douglas/Lockheed  32.9 m
# 8    Thorad SLV-2H Agena D  United States  Douglas/Lockheed    34 m
# 9      Thor-Burner-1 MG-18  United States           Douglas    23 m
# 10  Thor-Burner-1 Altair-3  United States           Douglas   ~24 m
# 11           Thor-Burner-2  United States           Douglas  22.4 m
# ...

# %% [markdown]
# ## Orbital Launch Families
#
# - <https://en.wikipedia.org/wiki/Comparison_of_orbital_launcher_families>

# %%
url_lf = 'https://en.wikipedia.org/wiki/Comparison_of_orbital_launcher_families'
dfs_lf = pd.read_html(url_lf)

# %%
dfs_lf[0]
# Out:
#        Family           Country/Org.           Manufac.  \
#        Family  Family.1 Country/Org.           Manufac.
# 0    Agnibaan  Agnibaan          IND     AgniKul Cosmos
# 1       Alpha     Alpha          USA  Firefly Aerospace
# 2      Angara    Angara          RUS         Khrunichev
# 3     Antares   Antares          USA        Orbital ATK
# 4    Ariane 6  Ariane 6     FRA  ESA        ArianeGroup
# ..        ...       ...          ...                ...
# 98   Zhuque-2  Zhuque-2          CHN          LandSpace
# 99   Zhuque-3  Zhuque-3          CHN          LandSpace
# 100  Zhuque-3  Zhuque-3          CHN          LandSpace
# 101  Zuljanah  Zuljanah          IRN                ISA
# 102         0       NaN          NaN                NaN
#
#                             Payload (kg)                      \
#                                      LEO                 GTO
# 0                                    100                  --
# ...

# %% [markdown]
# ### Retired Launch Families

# %%
dfs_lf[1]
# Out:
#                                 Family Country/Orgs.  \
#                                 Family Country/Orgs.
# 0                         Ariane 1-2-3      FRA  ESA
# 1                             Ariane 4      FRA  ESA
# 2                             Ariane 5      FRA  ESA
# 3                                 ASLV           IND
# 4                        Athena I & II           USA
# 5        Atlas I (Atlas A-B-C-D-E-F-G)           USA
# 6                             Atlas II           USA
# 7                            Atlas III           USA
# 8                          Black Arrow            UK
# 9                                Delta           USA
# 10                            Delta II           USA
# 11                           Delta III           USA
# 12                            Delta IV           USA
# 13                             Diamant           FRA
# 14                       Dnepr (R-36M)      UKR  RUS
# 15                             Energia          USSR
# ...

# %% [markdown]
# ## Orbital rocket engines
#
# - <https://en.wikipedia.org/wiki/Comparison_of_orbital_rocket_engines>

# %%
url_or = 'https://en.wikipedia.org/wiki/Comparison_of_orbital_rocket_engines'
dfs_or = pd.read_html(url_or)

# %%
dfs_or[0]
# Out:
#         Engine           Origin          Designer  \
# 0       Aeon-R              USA  Relativity Space
# 1    AJ-10-190              USA           Aerojet
# 2    Aquila SL          Germany    Isar Aerospace
# 3   Aquila VAC          Germany    Isar Aerospace
# 4   Archimedes  New Zealand USA        Rocket Lab
# ..         ...              ...               ...
# 78      YF-115            China             AALPT
# 79      YF-130            China             AALPT
# 80   Zefiro 9A           Europe              Avio
# 81   Zefiro 40           Europe              Avio
# 82      Zenith              USA             Stoke
#
#                              Vehicle       Status       Use  Propellant  \
# 0                           Terran R  Development  1st, 2nd   CH4 / LOX
# 1   Space Shuttle, Orion, Apollo CSM       Active     Upper  N2O4 / MMH
# 2                           Spectrum  Development       1st  C3H8 / LOX
# ...

# %%
dfs_or[1]
# Out:
#            Engine          Origin                  Designer  \
# 0          Aeon 1             USA          Relativity Space
# 1   Aeon 1 Vacuum             USA          Relativity Space
# 2          Aestus          Europe  Airbus Defence and Space
# 3       Aestus II          Europe  Airbus Defence and Space
# 4          Aether             USA               Astra Space
# ..            ...             ...                       ...
# 58       Viking 6          Europe                    Snecma
# 59  Vulcain HM-60          Europe                    Snecma
# 60      Vulcain 2          Europe                    Snecma
# 61        Waxwing  United Kingdom           Bristol Aerojet
# 62      Zefiro 23          Europe                      Avio
#
#                Vehicle   Status      Use      Propellant    Power cycle  \
# 0             Terran 1  Retired      1st       CH4 / LOX  Gas generator
# 1             Terran 1  Retired      2nd       CH4 / LOX  Gas generator
# ...
